# %%
import pandas as pd
import pyodbc
import os
from sql_pass import *

# Justin Do and Defne Sener 

password = sql_pass
username = 'justindo47'
default_db = "Fall_2022"
server = "localhost"    # has to be localhost not johndroescher unless using diff ide 
 
# either one must keep encrypt off and trust the server to prevent certification err
cnxn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};SERVER=%s;DATABASE=%s;UID=%s;PWD=%s;Encrypt=no;TrustServerCertificate=yes" %
    (server, default_db, username, password)
)
"""
Idea:
We follow good restaurants (now we need to find these "good" restaurants) 
    What do we need?
        - Score => Tells us their inspection grade regardless of null grades ( A (0-13) B (14-27) C (>=28) )
        - Record - Inspection Date => gives us the time they've been up
            -- (record date being "The date when the extract was run to produce this data set ")
        - Critical Flag => we CANNOT have critical violation bc => contribute to foodborne illness    

Explanation of SQL script:

WHERE dba NOT LIKE 'Test%' -->  Dba had Test test so we removed those (bc theyre testing)
WHERE score IS NOT NULL --> We need to know about their grades (less violation = better standing)

"""
sql_query = pd.read_sql("""
        SELECT dba,
               boro,
               zipcode,
               cuisine_description,
               score,
               grade,
               critical_flag,
               violation_description,
               inspection_date,
               record_date,
               datediff(year, inspection_date, record_date) as record_inspection_diff
        FROM restaurant_data as rd 
            LEFT JOIN violation_data as vd
                ON rd.camis = vd.camis
        WHERE dba NOT LIKE 'Test%' AND score IS NOT NULL
        """, con=cnxn)
# nyc_zip_codes = pd.read_csv(r'nyc-zip-codes.csv')
rest_viol_df = pd.DataFrame(sql_query)  # DataFrame Shape: (235989, 5) 235989 entries 5 columns

# Need to work with record_inspection_diff >= 5 yrs (5 yrs of bis could go up to 20 yrs --> generational = longevity)
rest_viol_df = rest_viol_df.loc[rest_viol_df['record_inspection_diff'] >= 5]

"""
We need to replace null Grades with our given score so... 
    - Instead of looping through each row and running a binary tree we should:
        - use loc to change values 
        - chain filters in the first argument using & 

Once we finish adding the grade values:
    - Let's double check that there are no null grades 
    - make a groupby with boro > grade > count
"""

# Base DataFrame
rest_viol_df.loc[(rest_viol_df['grade'].isnull()) & (rest_viol_df['score'] <= 13), 'grade'] = 'A'
rest_viol_df.loc[
    (rest_viol_df['grade'].isnull()) & (rest_viol_df['score'] > 13) & (rest_viol_df['score'] <= 27), 'grade'] = 'B'
rest_viol_df.loc[(rest_viol_df['grade'].isnull()) & (rest_viol_df['score'] >= 28), 'grade'] = 'C'
# sort by inspect date (desc high-low) most recent inspection (bc drop_dup will take the FIRST inspection it sees from dba)
rest_viol_df.sort_values(by=['inspection_date', 'score'], ascending=[0, 0], inplace=True)
print(rest_viol_df)
# Out:
#                                dba       boro zipcode cuisine_description  \
# 160690  FLAVAS INTERNATIONAL GRILL      Bronx   10451           Caribbean
# 163179  FLAVAS INTERNATIONAL GRILL      Bronx   10451           Caribbean
# 165809  FLAVAS INTERNATIONAL GRILL      Bronx   10451           Caribbean
# 183452  FLAVAS INTERNATIONAL GRILL      Bronx   10451           Caribbean
# 190475  FLAVAS INTERNATIONAL GRILL      Bronx   10451           Caribbean
# ...                            ...        ...     ...                 ...
# 233466                     ESCOLAS     Queens   11106      Latin American
# 235275                     ESCOLAS     Queens   11106      Latin American
# 144456                     ESCOLAS     Queens   11106      Latin American
# 177019                     ESCOLAS     Queens   11106      Latin American
# 179048      FALAFEL OFF THE CORNER  Manhattan   10128       Jewish/Kosher
#
#         score grade critical_flag  \
# 160690     44     C  Not Critical
# 163179     44     C  Not Critical
# 165809     44     C  Not Critical
# 183452     44     C  Not Critical
# 190475     44     C      Critical
# ...       ...   ...           ...
# 233466     13     A  Not Critical
# 235275     13     A      Critical
# 144456     10     A      Critical
# 177019     10     A  Not Critical
# 179048     10     A      Critical
#
#                                     violation_description inspection_date  \
# 160690  Non-food contact surface improperly constructe...      2017-12-29
# 163179  Non-food contact surface improperly constructe...      2017-12-29
# 165809  Non-food contact surface improperly constructe...      2017-12-29
# 183452  Facility not vermin proof. Harborage or condit...      2017-12-29
# 190475  Filth flies or food/refuse/sewage-associated (...      2017-12-29
# ...                                                   ...             ...
# 233466  Facility not vermin proof. Harborage or condit...      2015-07-08
# 235275  Filth flies or food/refuse/sewage-associated (...      2015-07-08
# 144456  Evidence of mice or live mice present in facil...      2015-06-25
# 177019  Facility not vermin proof. Harborage or condit...      2015-06-25
# 179048  Hand washing facility not provided in or near ...      2015-01-06
#
#                record_date  record_inspection_diff
# 160690 2022-08-27 06:00:12                       5
# 163179 2022-08-27 06:00:12                       5
# 165809 2022-08-27 06:00:12                       5
# 183452 2022-08-27 06:00:12                       5
# 190475 2022-08-27 06:00:12                       5
# ...                    ...                     ...
# 233466 2022-08-27 06:00:12                       7
# 235275 2022-08-27 06:00:12                       7
# 144456 2022-08-27 06:00:12                       7
# 177019 2022-08-27 06:00:12                       7
# 179048 2022-08-27 06:00:12                       7
#
# [11688 rows x 11 columns]

# %%
# no duplicate dba for cuisine counts --> keeps the first one that it sees
non_dup_rest_viol_df = rest_viol_df.drop_duplicates(subset=['dba']).loc[rest_viol_df['critical_flag'] != 'Critical']
print(non_dup_rest_viol_df)
# Out:
#                                        dba           boro zipcode  \
# 160690          FLAVAS INTERNATIONAL GRILL          Bronx   10451
# 72213   HEALTHY EATERS JAMAICAN RESTAURANT         Queens   11412
# 156378                                YVES      Manhattan   10013
# 14938                         ROUND 2 CAFE       Brooklyn   11203
# 61426              THE RIDGEWOOD ALE HOUSE         Queens   11385
# ...                                    ...            ...     ...
# 69174           ROMANCE BAR AND RESTAURANT  Staten Island   10303
# 139334                          RMM LOUNGE          Bronx   10455
# 58376                       LYCEUM THEATRE      Manhattan   10036
# 53611                MANHATTAN TERRACE BAR         Queens   11420
# 19778               FALAFEL OFF THE CORNER      Manhattan   10128
#
#        cuisine_description  score grade   critical_flag  \
# 160690           Caribbean     44     C    Not Critical
# 72213            Caribbean      7     A    Not Critical
# 156378            American      4     A    Not Critical
# 14938            Caribbean     57     C    Not Critical
# 61426             American     17     B    Not Critical
# ...                    ...    ...   ...             ...
# 69174       Latin American      9     A    Not Critical
# 139334            American      2     A    Not Critical
# 58376             American      2     A    Not Critical
# 53611             American      0     A  Not Applicable
# 19778        Jewish/Kosher     13     A    Not Critical
#
#                                     violation_description inspection_date  \
# 160690  Non-food contact surface improperly constructe...      2017-12-29
# 72213   Pesticide use not in accordance with label or ...      2017-12-29
# 156378  Non-food contact surface improperly constructe...      2017-12-29
# 14938   Plumbing not properly installed or maintained;...      2017-12-28
# 61426   Facility not vermin proof. Harborage or condit...      2017-12-28
# ...                                                   ...             ...
# 69174   Facility not vermin proof. Harborage or condit...      2016-06-08
# 139334      Food contact surface not properly maintained.      2016-06-03
# 58376   Non-food contact surface improperly constructe...      2016-05-14
# 53611                                                None      2016-05-14
# 19778   Plumbing not properly installed or maintained;...      2016-02-16
#
#                record_date  record_inspection_diff
# 160690 2022-08-27 06:00:12                       5
# 72213  2022-08-27 06:00:12                       5
# 156378 2022-08-27 06:00:12                       5
# 14938  2022-08-27 06:00:12                       5
# 61426  2022-08-27 06:00:12                       5
# ...                    ...                     ...
# 69174  2022-08-27 06:00:12                       6
# 139334 2022-08-27 06:00:12                       6
# 58376  2022-08-27 06:00:12                       6
# 53611  2022-08-27 06:00:12                       6
# 19778  2022-08-27 06:00:12                       6
#
# [1119 rows x 11 columns]

# %%
# Lower Competition with less cuisines
cuisine_groups = non_dup_rest_viol_df.groupby(['boro', 'cuisine_description']).count()
less_cuisine_groups = cuisine_groups.loc[cuisine_groups['dba'] <= 10]['dba']
print(less_cuisine_groups)
# Out:
# boro           cuisine_description
# Bronx          African                     2
#                Asian/Asian Fusion          1
#                Bakery Products/Desserts    2
#                Coffee/Tea                  4
#                Frozen Desserts             1
#                                           ..
# Staten Island  Japanese                    1
#                Latin American              1
#                Mexican                     2
#                Pizza                       2
#                Polish                      1
# Name: dba, Length: 143, dtype: int64

# %%
# We need to find out which restaurants have these cuisines so lets loops through the index and find the restaurant they counted
less_cuisine_df = pd.DataFrame()
for boro, cuisine_type in less_cuisine_groups.index:
    # for less_cuisine_df
    df = non_dup_rest_viol_df.loc[(non_dup_rest_viol_df['boro'] == boro) & (non_dup_rest_viol_df['cuisine_description'] == cuisine_type)]
    less_cuisine_df = pd.concat([less_cuisine_df, df])    # concat is not an in place function so lets update of df

print(less_cuisine_df)
# Out:
#                                                     dba           boro  \
# 79907                            MAMA G AFRICAN KITCHEN          Bronx
# 49577                        BRAVO AFRICAN RESTAURANT 2          Bronx
# 55460                               LIN'S ASIAN CUISINE          Bronx
# 11893                             CONTI'S PASTRY SHOPPE          Bronx
# 97792   AL CHOLO WEST INDIAN BAKERY & HEALTH FOOD STORE          Bronx
# ...                                                 ...            ...
# 25754                                       ADOBE BLUES  Staten Island
# 125347                                   EL LOBITO LOCO  Staten Island
# 16492                               PRIME PIZZA KITCHEN  Staten Island
# 133219                       TONY'S ORIGINAL'S PIZZERIA  Staten Island
# 158605                                     TERMINAL ONE  Staten Island
#
#        zipcode       cuisine_description  score grade critical_flag  \
# 79907    10467                   African     10     A  Not Critical
# 49577    10467                   African      7     A  Not Critical
# 55460    10462        Asian/Asian Fusion     15     B  Not Critical
# 11893    10462  Bakery Products/Desserts     10     A  Not Critical
# 97792    10467  Bakery Products/Desserts     10     A  Not Critical
# ...        ...                       ...    ...   ...           ...
# 25754    10301                   Mexican     13     A  Not Critical
# 125347   10302                   Mexican      9     A  Not Critical
# 16492    10305                     Pizza     12     A  Not Critical
# 133219   10301                     Pizza      9     A  Not Critical
# 158605   10305                    Polish      9     A  Not Critical
#
#                                     violation_description inspection_date  \
# 79907   Pesticide use not in accordance with label or ...      2017-12-05
# 49577   Mechanical or natural ventilation system not p...      2017-10-18
# 55460   Facility not vermin proof. Harborage or condit...      2017-11-17
# 11893   Facility not vermin proof. Harborage or condit...      2017-09-06
# 97792   Facility not vermin proof. Harborage or condit...      2017-06-21
# ...                                                   ...             ...
# 25754   Non-food contact surface improperly constructe...      2017-09-13
# 125347  Proper sanitization not provided for utensil w...      2017-03-22
# 16492   Plumbing not properly installed or maintained;...      2017-10-18
# 133219  Non-food contact surface improperly constructe...      2017-08-09
# 158605  Proper sanitization not provided for utensil w...      2017-01-24
#
#                record_date  record_inspection_diff
# 79907  2022-08-27 06:00:12                       5
# 49577  2022-08-27 06:00:12                       5
# 55460  2022-08-27 06:00:12                       5
# 11893  2022-08-27 06:00:12                       5
# 97792  2022-08-27 06:00:12                       5
# ...                    ...                     ...
# 25754  2022-08-27 06:00:12                       5
# 125347 2022-08-27 06:00:12                       5
# 16492  2022-08-27 06:00:12                       5
# 133219 2022-08-27 06:00:12                       5
# 158605 2022-08-27 06:00:12                       5
#
# [411 rows x 11 columns]

# %%
# Split our less_cuisines into A grades and B&C grades
a_less_cuisine_df = less_cuisine_df.loc[(less_cuisine_df['grade'] == 'A') & (less_cuisine_df['critical_flag'] != 'Critical')]
print(a_less_cuisine_df)
# Out:
#                                                       dba           boro  \
# 79907                              MAMA G AFRICAN KITCHEN          Bronx
# 49577                          BRAVO AFRICAN RESTAURANT 2          Bronx
# 11893                               CONTI'S PASTRY SHOPPE          Bronx
# 97792     AL CHOLO WEST INDIAN BAKERY & HEALTH FOOD STORE          Bronx
# 69406   FORDHAM U - SALT & SESAME AT FACULTY MEMORIAL ...          Bronx
# ...                                                   ...            ...
# 25754                                         ADOBE BLUES  Staten Island
# 125347                                     EL LOBITO LOCO  Staten Island
# 16492                                 PRIME PIZZA KITCHEN  Staten Island
# 133219                         TONY'S ORIGINAL'S PIZZERIA  Staten Island
# 158605                                       TERMINAL ONE  Staten Island
#
#        zipcode       cuisine_description  score grade critical_flag  \
# 79907    10467                   African     10     A  Not Critical
# 49577    10467                   African      7     A  Not Critical
# 11893    10462  Bakery Products/Desserts     10     A  Not Critical
# 97792    10467  Bakery Products/Desserts     10     A  Not Critical
# 69406    10458                Coffee/Tea      2     A  Not Critical
# ...        ...                       ...    ...   ...           ...
# 25754    10301                   Mexican     13     A  Not Critical
# 125347   10302                   Mexican      9     A  Not Critical
# 16492    10305                     Pizza     12     A  Not Critical
# 133219   10301                     Pizza      9     A  Not Critical
# 158605   10305                    Polish      9     A  Not Critical
#
#                                     violation_description inspection_date  \
# 79907   Pesticide use not in accordance with label or ...      2017-12-05
# 49577   Mechanical or natural ventilation system not p...      2017-10-18
# 11893   Facility not vermin proof. Harborage or condit...      2017-09-06
# 97792   Facility not vermin proof. Harborage or condit...      2017-06-21
# 69406   Non-food contact surface improperly constructe...      2017-11-30
# ...                                                   ...             ...
# 25754   Non-food contact surface improperly constructe...      2017-09-13
# 125347  Proper sanitization not provided for utensil w...      2017-03-22
# 16492   Plumbing not properly installed or maintained;...      2017-10-18
# 133219  Non-food contact surface improperly constructe...      2017-08-09
# 158605  Proper sanitization not provided for utensil w...      2017-01-24
#
#                record_date  record_inspection_diff
# 79907  2022-08-27 06:00:12                       5
# 49577  2022-08-27 06:00:12                       5
# 11893  2022-08-27 06:00:12                       5
# 97792  2022-08-27 06:00:12                       5
# 69406  2022-08-27 06:00:12                       5
# ...                    ...                     ...
# 25754  2022-08-27 06:00:12                       5
# 125347 2022-08-27 06:00:12                       5
# 16492  2022-08-27 06:00:12                       5
# 133219 2022-08-27 06:00:12                       5
# 158605 2022-08-27 06:00:12                       5
#
# [347 rows x 11 columns]

# %%
bc_less_cuisine_df = less_cuisine_df.loc[(less_cuisine_df['grade'] == 'B') | (less_cuisine_df['grade'] == 'C')].sort_values(by='grade', ascending=1)
print(bc_less_cuisine_df)
# Out:
#                                       dba           boro zipcode  \
# 55460                 LIN'S ASIAN CUISINE          Bronx   10462
# 3532        TEQUILA CHITO'S MEXICAN GRILL      Manhattan   10011
# 6866           COLES DOCK SIDE RESTAURANT  Staten Island   10308
# 7529                     LUNA CAFE LOUNGE      Manhattan   10003
# 45625                 KISS MY SLICE PIZZA      Manhattan   10022
# 113                                 SPICE      Manhattan   10003
# 10766                          THAI VILLA      Manhattan   10003
# 17243                             MAMALEE         Queens   11364
# 75487                       ASIAN GOURMET         Queens   11355
# 117013                   DHAKA RESTAURANT         Queens   11432
# 41640                        MAGGIE MAE'S         Queens   11104
# 20642                  CAFE MORNING OF NY         Queens   11358
# 11370                 SERBIAN ASSOCIATION         Queens   11385
# 106692          MARYANN'S WOODSIDE EVENTS         Queens   11377
# 119566               DIRTY PIERRES BISTRO         Queens   11375
# 25063                 STAMATIS RESTAURANT         Queens   11105
# 35479                         TAJ VILLAGE         Queens   11379
# 19252                          MASALA BOX         Queens   11361
# 44407                  TAQUERIA COATZINGO         Queens   11372
# 129078                       LAS CATRINAS         Queens   11106
# 120272             HOT AND JUICY CRAWFISH         Queens   11354
# 32124        IL SOGNO ITALIANO RISTORANTE  Staten Island   10312
# 52747                         LA PULPERIA      Manhattan   10028
# 52879                               MOKJA      Manhattan   10025
# 12707         LA NUEVA CARICIA RESTAURANT      Manhattan   10031
# 165543  ESPERANTO RESTAURANT BAR AND JUGO      Manhattan   10009
# 5106                            MOOD RING       Brooklyn   11221
# 6131                       GOOD FRIENDS 1       Brooklyn   11226
# 51698               SAN GERMAN CUCHIFRITO          Bronx   10459
# 10474                      ALENBI KITCHEN       Brooklyn   11225
# 55483                      PICADILLY HALL       Brooklyn   11230
# 55222                SHAARE ZION CATERERS       Brooklyn   11223
# 36095       LAS CAMELIAS BAR & RESTAURANT          Bronx   10472
# 1726                             RED MIST       Brooklyn   11218
# 73742                  RIVERDALE PIE GUYS          Bronx   10471
# 15538                        SHAKING CRAB       Brooklyn   11215
# 50200                RAZOR'S BAR & LOUNGE       Brooklyn   11206
# 20549     O! NIGIRI! THE RICEBALL FACTORY      Manhattan   10009
# 2240                              SAKAMAI      Manhattan   10002
# 52480   ORCHARD BEACH SNACK BAR SECTION 5          Bronx   10464
# 59349          APOLLO THEATRE CONCESSIONS      Manhattan   10027
# 42897                          LUX Lounge       Brooklyn   11219
# 33983                        OASIS KD BAR         Queens   11368
# 11416                                AGED         Queens   11375
# 22552         DOMINICK'S BAR & RESTAURANT          Bronx   10458
# 14569               LA CABANA SALVADORENA          Bronx   10468
# 13726                      BEAN'S & LAGER         Queens   11106
# 49891                       BICHEIROS BAR         Queens   11421
# 80333                         KUNG FU TEA         Queens   11361
# 8123                        GOOD TASTE 88       Brooklyn   11220
# 815               Davry Kosher Sports Bar       Brooklyn   11223
# 52498                            POKE BAR      Manhattan   10018
# 95556   GT RICEBOWL RESTAURANT AND LOUNGE         Queens   11419
# 3311                         L.A. BURRITO       Brooklyn   11238
# 39518                     MAOZ VEGETARIAN      Manhattan    None
# 21016                     LUI'S THAI FOOD      Manhattan   10003
# 171739                             BALADE      Manhattan   10009
# 134040                        LOBSTER BOX          Bronx   10464
# 46880            FUSHIMI JAPANESE CUISINE  Staten Island   10306
#
#        cuisine_description  score grade critical_flag  \
# 55460   Asian/Asian Fusion     15     B  Not Critical
# 3532               Mexican     20     B  Not Critical
# 6866               Italian     27     B  Not Critical
# 7529        Middle Eastern     18     B  Not Critical
# 45625                Pizza     15     B  Not Critical
# 113                   Thai     23     B  Not Critical
# 10766                 Thai     21     B  Not Critical
# 17243   Asian/Asian Fusion     24     B  Not Critical
# 75487   Asian/Asian Fusion     17     B  Not Critical
# 117013         Bangladeshi     17     B  Not Critical
# 41640    Bottled Beverages     17     B  Not Critical
# 20642           Coffee/Tea     22     B  Not Critical
# 11370     Eastern European     21     B  Not Critical
# 106692            Filipino     26     B  Not Critical
# 119566              French     14     B  Not Critical
# 25063                Greek     23     B  Not Critical
# 35479               Indian     23     B  Not Critical
# 19252               Indian     24     B  Not Critical
# 44407              Mexican     21     B  Not Critical
# 129078             Mexican     14     B  Not Critical
# 120272             Seafood     17     B  Not Critical
# 32124              Italian     16     B  Not Critical
# 52747       Latin American     16     B  Not Critical
# 52879               Korean     18     B  Not Critical
# 12707              Mexican     20     B  Not Critical
# 165543           Brazilian     14     B  Not Critical
# 5106    Asian/Asian Fusion     16     B  Not Critical
# 6131               Chinese     22     B  Not Critical
# 51698       Latin American     24     B  Not Critical
# 10474        Jewish/Kosher     21     B  Not Critical
# 55483        Jewish/Kosher     27     B  Not Critical
# 55222        Jewish/Kosher     21     B  Not Critical
# 36095       Latin American     18     B  Not Critical
# 1726        Middle Eastern     20     B  Not Critical
# 73742                Pizza     24     B  Not Critical
# 15538              Seafood     21     B  Not Critical
# 50200              Spanish     15     B  Not Critical
# 20549   Asian/Asian Fusion     15     B  Not Critical
# 2240    Asian/Asian Fusion     22     B  Not Critical
# 52480           Coffee/Tea     17     B  Not Critical
# 59349    Bottled Beverages     18     B  Not Critical
# 42897                Other     21     B  Not Critical
# 33983              Spanish     33     C  Not Critical
# 11416           Steakhouse     35     C  Not Critical
# 22552              Italian     31     C  Not Critical
# 14569       Latin American     36     C  Not Critical
# 13726        Mediterranean     35     C  Not Critical
# 49891              Spanish     28     C  Not Critical
# 80333           Coffee/Tea     63     C  Not Critical
# 8123               Chinese     46     C  Not Critical
# 815          Jewish/Kosher     32     C  Not Critical
# 52498             Hawaiian     49     C  Not Critical
# 95556            Caribbean     34     C  Not Critical
# 3311               Mexican     30     C  Not Critical
# 39518           Vegetarian      2     C  Not Critical
# 21016                 Thai      2     C  Not Critical
# 171739       Mediterranean      2     C  Not Critical
# 134040             Seafood      4     C  Not Critical
# 46880             Japanese     35     C  Not Critical
#
#                                     violation_description inspection_date  \
# 55460   Facility not vermin proof. Harborage or condit...      2017-11-17
# 3532    Plumbing not properly installed or maintained;...      2017-12-18
# 6866    Proper sanitization not provided for utensil w...      2017-05-31
# 7529    Proper sanitization not provided for utensil w...      2017-11-27
# 45625   Proper sanitization not provided for utensil w...      2017-09-12
# 113     Facility not vermin proof. Harborage or condit...      2017-05-22
# 10766                        Thawing procedures improper.      2017-05-02
# 17243   Plumbing not properly installed or maintained;...      2017-12-21
# 75487   Non-food contact surface improperly constructe...      2017-12-11
# 117013  Pesticide use not in accordance with label or ...      2017-10-05
# 41640   Facility not vermin proof. Harborage or condit...      2017-12-20
# 20642   Facility not vermin proof. Harborage or condit...      2017-04-24
# 11370   Pesticide use not in accordance with label or ...      2017-07-14
# 106692  Pesticide use not in accordance with label or ...      2017-09-22
# 119566  Plumbing not properly installed or maintained;...      2017-02-07
# 25063   Pesticide use not in accordance with label or ...      2017-12-20
# 35479   Non-food contact surface improperly constructe...      2017-11-03
# 19252   Plumbing not properly installed or maintained;...      2017-07-25
# 44407   Facility not vermin proof. Harborage or condit...      2017-12-11
# 129078  Non-food contact surface improperly constructe...      2017-10-25
# 120272  Proper sanitization not provided for utensil w...      2017-12-13
# 32124   Pesticide use not in accordance with label or ...      2017-08-08
# 52747   Facility not vermin proof. Harborage or condit...      2017-10-11
# 52879   Pesticide use not in accordance with label or ...      2017-11-29
# 12707   Non-food contact surface improperly constructe...      2017-06-14
# 165543  Facility not vermin proof. Harborage or condit...      2017-12-18
# 5106    Proper sanitization not provided for utensil w...      2017-11-24
# 6131    Non-food contact surface improperly constructe...      2017-03-29
# 51698   Plumbing not properly installed or maintained;...      2017-07-29
# 10474   Plumbing not properly installed or maintained;...      2017-11-30
# 55483   Facility not vermin proof. Harborage or condit...      2017-09-07
# 55222   Plumbing not properly installed or maintained;...      2016-12-13
# 36095   Facility not vermin proof. Harborage or condit...      2017-04-11
# 1726    Facility not vermin proof. Harborage or condit...      2017-10-28
# 73742   Facility not vermin proof. Harborage or condit...      2017-11-21
# 15538   Plumbing not properly installed or maintained;...      2017-12-13
# 50200   Plumbing not properly installed or maintained;...      2017-06-29
# 20549   Toilet facility not maintained and provided wi...      2017-12-12
# 2240    Non-food contact surface improperly constructe...      2017-09-20
# 52480   Plumbing not properly installed or maintained;...      2017-08-17
# 59349   Facility not vermin proof. Harborage or condit...      2017-08-09
# 42897   Facility not vermin proof. Harborage or condit...      2016-09-29
# 33983   Facility not vermin proof. Harborage or condit...      2017-08-05
# 11416   Non-food contact surface improperly constructe...      2017-12-21
# 22552   Plumbing not properly installed or maintained;...      2017-10-23
# 14569   Facility not vermin proof. Harborage or condit...      2017-12-18
# 13726                           Hand wash sign not posted      2017-10-11
# 49891   Pesticide use not in accordance with label or ...      2017-12-09
# 80333   Plumbing not properly installed or maintained;...      2017-10-23
# 8123        Food contact surface not properly maintained.      2017-11-06
# 815     Non-food contact surface improperly constructe...      2017-12-13
# 52498   Accurate thermometer not provided in refrigera...      2017-12-18
# 95556   Plumbing not properly installed or maintained;...      2017-11-30
# 3311    Facility not vermin proof. Harborage or condit...      2017-09-27
# 39518   Plumbing not properly installed or maintained;...      2017-07-03
# 21016   Non-food contact surface improperly constructe...      2017-07-14
# 171739  Non-food contact surface improperly constructe...      2017-10-26
# 134040  Non-food contact surface improperly constructe...      2017-10-20
# 46880   Facility not vermin proof. Harborage or condit...      2017-07-10
#
#                record_date  record_inspection_diff
# 55460  2022-08-27 06:00:12                       5
# 3532   2022-08-27 06:00:12                       5
# 6866   2022-08-27 06:00:12                       5
# 7529   2022-08-27 06:00:12                       5
# 45625  2022-08-27 06:00:12                       5
# 113    2022-08-27 06:00:12                       5
# 10766  2022-08-27 06:00:12                       5
# 17243  2022-08-27 06:00:12                       5
# 75487  2022-08-27 06:00:12                       5
# 117013 2022-08-27 06:00:12                       5
# 41640  2022-08-27 06:00:12                       5
# 20642  2022-08-27 06:00:12                       5
# 11370  2022-08-27 06:00:12                       5
# 106692 2022-08-27 06:00:12                       5
# 119566 2022-08-27 06:00:12                       5
# 25063  2022-08-27 06:00:12                       5
# 35479  2022-08-27 06:00:12                       5
# 19252  2022-08-27 06:00:12                       5
# 44407  2022-08-27 06:00:12                       5
# 129078 2022-08-27 06:00:12                       5
# 120272 2022-08-27 06:00:12                       5
# 32124  2022-08-27 06:00:12                       5
# 52747  2022-08-27 06:00:12                       5
# 52879  2022-08-27 06:00:12                       5
# 12707  2022-08-27 06:00:12                       5
# 165543 2022-08-27 06:00:12                       5
# 5106   2022-08-27 06:00:12                       5
# 6131   2022-08-27 06:00:12                       5
# 51698  2022-08-27 06:00:12                       5
# 10474  2022-08-27 06:00:12                       5
# 55483  2022-08-27 06:00:12                       5
# 55222  2022-08-27 06:00:12                       6
# 36095  2022-08-27 06:00:12                       5
# 1726   2022-08-27 06:00:12                       5
# 73742  2022-08-27 06:00:12                       5
# 15538  2022-08-27 06:00:12                       5
# 50200  2022-08-27 06:00:12                       5
# 20549  2022-08-27 06:00:12                       5
# 2240   2022-08-27 06:00:12                       5
# 52480  2022-08-27 06:00:12                       5
# 59349  2022-08-27 06:00:12                       5
# 42897  2022-08-27 06:00:12                       6
# 33983  2022-08-27 06:00:12                       5
# 11416  2022-08-27 06:00:12                       5
# 22552  2022-08-27 06:00:12                       5
# 14569  2022-08-27 06:00:12                       5
# 13726  2022-08-27 06:00:12                       5
# 49891  2022-08-27 06:00:12                       5
# 80333  2022-08-27 06:00:12                       5
# 8123   2022-08-27 06:00:12                       5
# 815    2022-08-27 06:00:12                       5
# 52498  2022-08-27 06:00:12                       5
# 95556  2022-08-27 06:00:12                       5
# 3311   2022-08-27 06:00:12                       5
# 39518  2022-08-27 06:00:12                       5
# 21016  2022-08-27 06:00:12                       5
# 171739 2022-08-27 06:00:12                       5
# 134040 2022-08-27 06:00:12                       5
# 46880  2022-08-27 06:00:12                       5

# %%
# We need to compare A and BC grades 
a_viol_info_df = a_less_cuisine_df[['dba', 'boro', 'cuisine_description', 'grade', 'critical_flag', 'violation_description', 'inspection_date' ]]
# less_cuisine_groups = cuisine_groups.loc[cuisine_groups['dba'] <= 10]['dba']
a_viol_info_group = a_viol_info_df.groupby(['boro', 'cuisine_description']).count()
a_viol_info_group = a_viol_info_group.loc[a_viol_info_group['dba'] <= 3]['dba']
print(a_viol_info_group)
# Out:
# boro           cuisine_description
# Bronx          African                     2
#                Bakery Products/Desserts    2
#                Coffee/Tea                  2
#                Frozen Desserts             1
#                Greek                       1
#                                           ..
# Staten Island  Indian                      1
#                Latin American              1
#                Mexican                     2
#                Pizza                       2
#                Polish                      1
# Name: dba, Length: 101, dtype: int64

# %%
bc_viol_info_df = bc_less_cuisine_df[['dba', 'boro', 'cuisine_description', 'grade', 'critical_flag', 'violation_description', 'inspection_date' ]]
bc_viol_info_group = bc_viol_info_df.groupby(['boro', 'cuisine_description']).count()
print(bc_viol_info_group)
# Out:
#                                    dba  grade  critical_flag  \
# boro          cuisine_description
# Bronx         Asian/Asian Fusion     1      1              1
#               Coffee/Tea             1      1              1
#               Italian                1      1              1
#               Latin American         3      3              3
#               Pizza                  1      1              1
#               Seafood                1      1              1
# Brooklyn      Asian/Asian Fusion     1      1              1
#               Chinese                2      2              2
#               Jewish/Kosher          4      4              4
#               Mexican                1      1              1
#               Middle Eastern         1      1              1
#               Other                  1      1              1
#               Seafood                1      1              1
#               Spanish                1      1              1
# Manhattan     Asian/Asian Fusion     2      2              2
#               Bottled Beverages      1      1              1
#               Brazilian              1      1              1
#               Hawaiian               1      1              1
#               Korean                 1      1              1
#               Latin American         1      1              1
#               Mediterranean          1      1              1
#               Mexican                2      2              2
#               Middle Eastern         1      1              1
#               Pizza                  1      1              1
#               Thai                   3      3              3
#               Vegetarian             1      1              1
# Queens        Asian/Asian Fusion     2      2              2
#               Bangladeshi            1      1              1
#               Bottled Beverages      1      1              1
#               Caribbean              1      1              1
#               Coffee/Tea             2      2              2
#               Eastern European       1      1              1
#               Filipino               1      1              1
#               French                 1      1              1
#               Greek                  1      1              1
#               Indian                 2      2              2
#               Mediterranean          1      1              1
#               Mexican                2      2              2
#               Seafood                1      1              1
#               Spanish                2      2              2
#               Steakhouse             1      1              1
# Staten Island Italian                2      2              2
#               Japanese               1      1              1
#
#                                    violation_description  inspection_date
# boro          cuisine_description
# Bronx         Asian/Asian Fusion                       1                1
#               Coffee/Tea                               1                1
#               Italian                                  1                1
#               Latin American                           3                3
#               Pizza                                    1                1
#               Seafood                                  1                1
# Brooklyn      Asian/Asian Fusion                       1                1
#               Chinese                                  2                2
#               Jewish/Kosher                            4                4
#               Mexican                                  1                1
#               Middle Eastern                           1                1
#               Other                                    1                1
#               Seafood                                  1                1
#               Spanish                                  1                1
# Manhattan     Asian/Asian Fusion                       2                2
#               Bottled Beverages                        1                1
#               Brazilian                                1                1
#               Hawaiian                                 1                1
#               Korean                                   1                1
#               Latin American                           1                1
#               Mediterranean                            1                1
#               Mexican                                  2                2
#               Middle Eastern                           1                1
#               Pizza                                    1                1
#               Thai                                     3                3
#               Vegetarian                               1                1
# Queens        Asian/Asian Fusion                       2                2
#               Bangladeshi                              1                1
#               Bottled Beverages                        1                1
#               Caribbean                                1                1
#               Coffee/Tea                               2                2
#               Eastern European                         1                1
#               Filipino                                 1                1
#               French                                   1                1
#               Greek                                    1                1
#               Indian                                   2                2
#               Mediterranean                            1                1
#               Mexican                                  2                2
#               Seafood                                  1                1
#               Spanish                                  2                2
#               Steakhouse                               1                1
# Staten Island Italian                                  2                2
#               Japanese                                 1                1

# %%
# Combined Dataframe with cuisine descriptions that have a grade of A AND B&C  
abc_viol_info_df = pd.DataFrame()
for boro, cuisine in bc_viol_info_group.index:
    if (boro, cuisine) in a_viol_info_group.index:
        df = non_dup_rest_viol_df.loc[(non_dup_rest_viol_df['boro'] == boro) & (non_dup_rest_viol_df['cuisine_description'] == cuisine)]
        abc_viol_info_df = pd.concat([abc_viol_info_df, df])

# %%
# Counting the Grades in each boro/cuisine
abc_viol_info_group = abc_viol_info_df.groupby(['boro', 'cuisine_description', 'grade'])['dba'].count()

# %%
# Final Frame for decision making
split_a_viol_info = abc_viol_info_df.loc[abc_viol_info_df['grade'] == 'A'].sort_values(by=['boro', 'cuisine_description'], ascending=[0,0])
print(split_a_viol_info)
# Out:
#                                                       dba       boro zipcode  \
# 42309                                            RW PRIME     Queens   11420
# 32486                             BOCA JUNIORS STEAKHOUSE     Queens   11373
# 27485                               LUNERA MODERN MEXICAN     Queens   11103
# 29846                                        CASA GALICIA     Queens   11103
# 14745                                            EL TUCAN     Queens   11373
# 135966                       OFF THE HOOK RAW BAR & GRILL     Queens   11103
# 111436                                             ANGLER     Queens   11369
# 76650                            MELODY CAFE & RESTAURANT     Queens   11103
# 77666                                               DUZAN     Queens   11103
# 45026                                   AIR FRANCE LOUNGE     Queens    None
# 72213                  HEALTHY EATERS JAMAICAN RESTAURANT     Queens   11412
# 105197              GOLDEN KRUST CARIBBEAN BAKERY & GRILL     Queens   11413
# 55291                                     LORNAS TAKE OUT     Queens   11434
# 39511                                     TASTE OF BENGAL     Queens   11102
# 48296                         MOTHER OF PEARL, HONEY BEES  Manhattan   10009
# 22773                                      SEASONED VEGAN  Manhattan   10026
# 76728                                            TOP THAI  Manhattan   10012
# 6632                                        THAI TERMINAL  Manhattan   10003
# 72385                    JAIYA THAI & ORIENTAL RESTAURANT  Manhattan   10028
# 36198                                   SALAM CAFE & REST  Manhattan   10011
# 25533                                          LIBERTADOR   Brooklyn   11201
# 181310                                              MAITE   Brooklyn   11221
# 61745                             SAINT JULIVERT FISHERIE   Brooklyn   11201
# 189940                                         PARC OASIS   Brooklyn   11219
# 48719                                REAZON CAFE & LOUNGE   Brooklyn   11230
# 119897                          MYST HOOKAH LOUNGE & CAFE   Brooklyn   11223
# 119301                                     COCONUT HOOKAH   Brooklyn   11220
# 77720                                  NEW PEKING KITCHEN   Brooklyn   11230
# 74610                                          NANA RAMEN   Brooklyn   11233
# 106254                                             SNACKY   Brooklyn   11211
# 19037                         COME & GET SUM FISH & CHIPS      Bronx   10456
# 57359                           JP'S WATERSIDE RESTAURANT      Bronx   10464
# 32467                         SAMMY'S ORIGINAL SHRIMP BOX      Bronx   10464
# 69406   FORDHAM U - SALT & SESAME AT FACULTY MEMORIAL ...      Bronx   10458
# 147094                                    GRIZZLY GROUNDS      Bronx   10460
#
#        cuisine_description  score grade critical_flag  \
# 42309           Steakhouse      7     A  Not Critical
# 32486           Steakhouse      9     A  Not Critical
# 27485              Spanish     13     A  Not Critical
# 29846              Spanish     11     A  Not Critical
# 14745              Spanish     13     A  Not Critical
# 135966             Seafood     12     A  Not Critical
# 111436             Seafood      7     A  Not Critical
# 76650        Mediterranean      7     A  Not Critical
# 77666        Mediterranean     10     A  Not Critical
# 45026               French      7     A  Not Critical
# 72213            Caribbean      7     A  Not Critical
# 105197           Caribbean      4     A  Not Critical
# 55291            Caribbean     11     A  Not Critical
# 39511          Bangladeshi     12     A  Not Critical
# 48296           Vegetarian     10     A  Not Critical
# 22773           Vegetarian      8     A  Not Critical
# 76728                 Thai     10     A  Not Critical
# 6632                  Thai     13     A  Not Critical
# 72385                 Thai      7     A  Not Critical
# 36198       Middle Eastern     11     A  Not Critical
# 25533              Spanish     12     A  Not Critical
# 181310             Spanish      3     A  Not Critical
# 61745              Seafood      7     A  Not Critical
# 189940             Seafood     11     A  Not Critical
# 48719                Other      2     A  Not Critical
# 119897      Middle Eastern     13     A  Not Critical
# 119301      Middle Eastern      2     A  Not Critical
# 77720              Chinese      9     A  Not Critical
# 74610   Asian/Asian Fusion      2     A  Not Critical
# 106254  Asian/Asian Fusion      2     A  Not Critical
# 19037              Seafood     13     A  Not Critical
# 57359              Seafood     10     A  Not Critical
# 32467              Seafood      9     A  Not Critical
# 69406           Coffee/Tea      2     A  Not Critical
# 147094          Coffee/Tea      2     A  Not Critical
#
#                                     violation_description inspection_date  \
# 42309   Proper sanitization not provided for utensil w...      2017-12-16
# 32486   Mechanical or natural ventilation system not p...      2017-07-06
# 27485   Non-food contact surface improperly constructe...      2017-09-12
# 29846   Plumbing not properly installed or maintained;...      2017-02-28
# 14745   Facility not vermin proof. Harborage or condit...      2017-02-15
# 135966  Facility not vermin proof. Harborage or condit...      2017-11-20
# 111436  Non-food contact surface improperly constructe...      2017-05-24
# 76650   Non-food contact surface improperly constructe...      2017-11-16
# 77666   Facility not vermin proof. Harborage or condit...      2017-08-02
# 45026   Non-food contact surface improperly constructe...      2017-06-21
# 72213   Pesticide use not in accordance with label or ...      2017-12-29
# 105197  Mechanical or natural ventilation system not p...      2017-08-21
# 55291   Facility not vermin proof. Harborage or condit...      2017-04-01
# 39511   Non-food contact surface improperly constructe...      2017-05-23
# 48296   Facility not vermin proof. Harborage or condit...      2017-12-19
# 22773   Non-food contact surface improperly constructe...      2017-08-19
# 76728   Non-food contact surface improperly constructe...      2017-12-21
# 6632    Facility not vermin proof. Harborage or condit...      2017-06-02
# 72385   Plumbing not properly installed or maintained;...      2017-04-13
# 36198   Non-food contact surface improperly constructe...      2017-07-17
# 25533   Non-food contact surface improperly constructe...      2017-12-20
# 181310  Non-food contact surface improperly constructe...      2017-06-06
# 61745   Non-food contact surface improperly constructe...      2017-10-12
# 189940  Facility not vermin proof. Harborage or condit...      2017-06-15
# 48719   Proper sanitization not provided for utensil w...      2017-02-09
# 119897  Facility not vermin proof. Harborage or condit...      2017-07-19
# 119301  Mechanical or natural ventilation system not p...      2016-11-12
# 77720   Non-food contact surface improperly constructe...      2017-08-03
# 74610   Non-food contact surface improperly constructe...      2017-12-05
# 106254  Single service item reused, improperly stored,...      2017-08-24
# 19037   Facility not vermin proof. Harborage or condit...      2017-12-06
# 57359   Plumbing not properly installed or maintained;...      2017-07-26
# 32467   Non-food contact surface improperly constructe...      2017-07-25
# 69406   Non-food contact surface improperly constructe...      2017-11-30
# 147094  Non-food contact surface improperly constructe...      2017-06-13
#
#                record_date  record_inspection_diff
# 42309  2022-08-27 06:00:12                       5
# 32486  2022-08-27 06:00:12                       5
# 27485  2022-08-27 06:00:12                       5
# 29846  2022-08-27 06:00:12                       5
# 14745  2022-08-27 06:00:12                       5
# 135966 2022-08-27 06:00:12                       5
# 111436 2022-08-27 06:00:12                       5
# 76650  2022-08-27 06:00:12                       5
# 77666  2022-08-27 06:00:12                       5
# 45026  2022-08-27 06:00:12                       5
# 72213  2022-08-27 06:00:12                       5
# 105197 2022-08-27 06:00:12                       5
# 55291  2022-08-27 06:00:12                       5
# 39511  2022-08-27 06:00:12                       5
# 48296  2022-08-27 06:00:12                       5
# 22773  2022-08-27 06:00:12                       5
# 76728  2022-08-27 06:00:12                       5
# 6632   2022-08-27 06:00:12                       5
# 72385  2022-08-27 06:00:12                       5
# 36198  2022-08-27 06:00:12                       5
# 25533  2022-08-27 06:00:12                       5
# 181310 2022-08-27 06:00:12                       5
# 61745  2022-08-27 06:00:12                       5
# 189940 2022-08-27 06:00:12                       5
# 48719  2022-08-27 06:00:12                       5
# 119897 2022-08-27 06:00:12                       5
# 119301 2022-08-27 06:00:12                       6
# 77720  2022-08-27 06:00:12                       5
# 74610  2022-08-27 06:00:12                       5
# 106254 2022-08-27 06:00:12                       5
# 19037  2022-08-27 06:00:12                       5
# 57359  2022-08-27 06:00:12                       5
# 32467  2022-08-27 06:00:12                       5
# 69406  2022-08-27 06:00:12                       5
# 147094 2022-08-27 06:00:12                       5

# %%
split_bc_viol_info = abc_viol_info_df.loc[(abc_viol_info_df['grade'] == 'B') | (abc_viol_info_df['grade'] == 'C')].sort_values(by=['boro','score'], ascending=[0,0])
print(split_bc_viol_info)
# Out:
#                                       dba       boro zipcode  \
# 13726                      BEAN'S & LAGER     Queens   11106
# 11416                                AGED     Queens   11375
# 95556   GT RICEBOWL RESTAURANT AND LOUNGE     Queens   11419
# 33983                        OASIS KD BAR     Queens   11368
# 49891                       BICHEIROS BAR     Queens   11421
# 117013                   DHAKA RESTAURANT     Queens   11432
# 120272             HOT AND JUICY CRAWFISH     Queens   11354
# 119566               DIRTY PIERRES BISTRO     Queens   11375
# 113                                 SPICE  Manhattan   10003
# 10766                          THAI VILLA  Manhattan   10003
# 7529                     LUNA CAFE LOUNGE  Manhattan   10003
# 21016                     LUI'S THAI FOOD  Manhattan   10003
# 39518                     MAOZ VEGETARIAN  Manhattan    None
# 8123                        GOOD TASTE 88   Brooklyn   11220
# 6131                       GOOD FRIENDS 1   Brooklyn   11226
# 42897                          LUX Lounge   Brooklyn   11219
# 15538                        SHAKING CRAB   Brooklyn   11215
# 1726                             RED MIST   Brooklyn   11218
# 5106                            MOOD RING   Brooklyn   11221
# 50200                RAZOR'S BAR & LOUNGE   Brooklyn   11206
# 52480   ORCHARD BEACH SNACK BAR SECTION 5      Bronx   10464
# 134040                        LOBSTER BOX      Bronx   10464
#
#        cuisine_description  score grade critical_flag  \
# 13726        Mediterranean     35     C  Not Critical
# 11416           Steakhouse     35     C  Not Critical
# 95556            Caribbean     34     C  Not Critical
# 33983              Spanish     33     C  Not Critical
# 49891              Spanish     28     C  Not Critical
# 117013         Bangladeshi     17     B  Not Critical
# 120272             Seafood     17     B  Not Critical
# 119566              French     14     B  Not Critical
# 113                   Thai     23     B  Not Critical
# 10766                 Thai     21     B  Not Critical
# 7529        Middle Eastern     18     B  Not Critical
# 21016                 Thai      2     C  Not Critical
# 39518           Vegetarian      2     C  Not Critical
# 8123               Chinese     46     C  Not Critical
# 6131               Chinese     22     B  Not Critical
# 42897                Other     21     B  Not Critical
# 15538              Seafood     21     B  Not Critical
# 1726        Middle Eastern     20     B  Not Critical
# 5106    Asian/Asian Fusion     16     B  Not Critical
# 50200              Spanish     15     B  Not Critical
# 52480           Coffee/Tea     17     B  Not Critical
# 134040             Seafood      4     C  Not Critical
#
#                                     violation_description inspection_date  \
# 13726                           Hand wash sign not posted      2017-10-11
# 11416   Non-food contact surface improperly constructe...      2017-12-21
# 95556   Plumbing not properly installed or maintained;...      2017-11-30
# 33983   Facility not vermin proof. Harborage or condit...      2017-08-05
# 49891   Pesticide use not in accordance with label or ...      2017-12-09
# 117013  Pesticide use not in accordance with label or ...      2017-10-05
# 120272  Proper sanitization not provided for utensil w...      2017-12-13
# 119566  Plumbing not properly installed or maintained;...      2017-02-07
# 113     Facility not vermin proof. Harborage or condit...      2017-05-22
# 10766                        Thawing procedures improper.      2017-05-02
# 7529    Proper sanitization not provided for utensil w...      2017-11-27
# 21016   Non-food contact surface improperly constructe...      2017-07-14
# 39518   Plumbing not properly installed or maintained;...      2017-07-03
# 8123        Food contact surface not properly maintained.      2017-11-06
# 6131    Non-food contact surface improperly constructe...      2017-03-29
# 42897   Facility not vermin proof. Harborage or condit...      2016-09-29
# 15538   Plumbing not properly installed or maintained;...      2017-12-13
# 1726    Facility not vermin proof. Harborage or condit...      2017-10-28
# 5106    Proper sanitization not provided for utensil w...      2017-11-24
# 50200   Plumbing not properly installed or maintained;...      2017-06-29
# 52480   Plumbing not properly installed or maintained;...      2017-08-17
# 134040  Non-food contact surface improperly constructe...      2017-10-20
#
#                record_date  record_inspection_diff
# 13726  2022-08-27 06:00:12                       5
# 11416  2022-08-27 06:00:12                       5
# 95556  2022-08-27 06:00:12                       5
# 33983  2022-08-27 06:00:12                       5
# 49891  2022-08-27 06:00:12                       5
# 117013 2022-08-27 06:00:12                       5
# 120272 2022-08-27 06:00:12                       5
# 119566 2022-08-27 06:00:12                       5
# 113    2022-08-27 06:00:12                       5
# 10766  2022-08-27 06:00:12                       5
# 7529   2022-08-27 06:00:12                       5
# 21016  2022-08-27 06:00:12                       5
# 39518  2022-08-27 06:00:12                       5
# 8123   2022-08-27 06:00:12                       5
# 6131   2022-08-27 06:00:12                       5
# 42897  2022-08-27 06:00:12                       6
# 15538  2022-08-27 06:00:12                       5
# 1726   2022-08-27 06:00:12                       5
# 5106   2022-08-27 06:00:12                       5
# 50200  2022-08-27 06:00:12                       5
# 52480  2022-08-27 06:00:12                       5
# 134040 2022-08-27 06:00:12                       5
